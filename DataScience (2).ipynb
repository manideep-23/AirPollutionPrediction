# %%
 import numpy as np
import pandas as pd
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive

# %%
# !ls
# Out:
# '305836 (1).pdf'
# '4B(READ HIGHLIGHTED(YELLOW)) BD.pdf'
# '7th sem'
# 'akash 001.jpg'
#  B612_20180212_205114.mp4
#  capgemini-16881A1238.pdf
#  car.jpeg
# 'CC lecture Notes unit-1(a).pdf'
# 'CC lecture Notes unit-1(b).pdf'
# 'cc notes.pdf'
# 'CC unit-1.docx'
# 'CC unit-2.docx'
# 'Chinna 👻#🖤'
#  classification.pdf
#  classifiers.pptx
#  club.rar
# 'Colab Notebooks'
#  College_Authorization_letter_new_7Jan.gdoc
# 'Copy of servlet_db.rar'
#  DAA-1.pdf
#  daa_all.pdf
#  DataAnalytics_4.ipynb
# 'Database Designing (1).doc'
# 'Database Designing (1).pdf'
# 'Database Designing.doc'
# 'Database Designing.pdf'
# 'datam (1).csv'
# 'datam (2).csv'
#  datam.csv
# 'DataScience _4.ipynb'
#  design_and_analysis_of_algorithms_tutorial.pdf-1.pdf
# 'Design Patterns Notes.gdoc'
# 'DIGITAL TWIN TECHNOLOGY.gslides'
# 'DIGITAL TWIN TECHNOLOGY.pptx'
#  DSC_2798.jpg
#  Farewell@2019
# 'Final Sem'
# 'Help Accident'
# 'How to get started with Drive (1).pdf'
# 'How to get started with Drive.pdf'
#  Imagedetection.webm
#  IMG_5212.JPG
#  IMG_5213.JPG
#  IMG_5214.JPG
# 'important '
#  imp_python
#  imp_python.7z
# 'Introduction to DBMS (1).pdf'
# 'Introduction to DBMS.pdf'
#  IS-4.rar
# 'IT_A_Technical_Seminar_Topics (1).gsheet'
# 'IT_A_Technical_Seminar_Topics (2).gsheet'
#  IT_A_Technical_Seminar_Topics.gsheet
#  login.php
# 'Major_analysis (1).ipynb'
#  Major_analysis.ipynb
#  major_analysis_output.webm
# 'Major_Datascience (1).ipynb'
# 'Major_Datascience (2).ipynb'
#  Major_Datascience.ipynb
#  major_Datascience_output.webm
# 'Major_project abstract2.docx'
# 'Major_project abstract2.gdoc'
# 'murali Anna pelli'
# 'New Doc 2019-03-31 11.31.18.pdf'
# 'NP-HARD AND NP-COMPLETE PROBLEMS-1.pdf'
# 'play boy@jashu'
# 'PL SQL and Triggers (1).pdf'
# 'PL SQL and Triggers.pdf'
# 'PML UNIT 3.1.pdf'
# 'PML UNIT 3.2.pdf'
# 'PML - UNIT-4.pptx'
# 'PML - UNIT - 5.pptx'
# 'Pondi pics'
#  presentation1.webm
#  presentation2.webm
#  prezi-windows.exe
#  prin.py
#  projects
#  question_1.jpeg
# 'QUESTIONS IMP TOPICS DATA BOOK.doc'
#  reg.php
# 'Relational algebra and Calculus (1).pdf'
# 'Relational algebra and Calculus.pdf'
# 'RELATIONAL MODEL (1).pdf'
# 'RELATIONAL MODEL.pdf'
#  Resume.docx
# 'Screenshot (1336).png'
# 'Screenshot (1337).png'
# 'Screenshot (1338).png'
# 'Screenshot (1339).png'
# 'Screenshot (1340).png'
# 'Screenshot (1341).png'
# 'Screenshot (1342).png'
# 'Screenshot (1343).png'
# 'Screenshot (1344).png'
# 'Screenshot (1345).png'
# 'Screenshot (1346).png'
# 'Screenshot (1347).png'
# 'Screenshot (1355) (1).png'
# 'Screenshot (1355).png'
# 'Screenshot (1356) (1).png'
# 'Screenshot (1356).png'
# 'Screenshot (1357) (1).png'
# 'Screenshot (1357).png'
# 'Screenshot (1358) (1).png'
# 'Screenshot (1358).png'
# 'Screenshot (1359) (1).png'
# 'Screenshot (1359) (2).png'
# 'Screenshot (1359).png'
# 'Screenshot (1360) (1).png'
# 'Screenshot (1360) (2).png'
# 'Screenshot (1360).png'
# 'Screenshot (1361) (1).png'
# 'Screenshot (1361) (2).png'
# 'Screenshot (1361).png'
# 'Screenshot (1362) (1).png'
# 'Screenshot (1362).png'
# 'Screenshot (1363).png'
# 'Screenshot (1364).png'
# 'Screenshot (1365).png'
# 'Screenshot (1366).png'
# 'Screenshot (253).png'
# 'Screenshot (254).png'
# 'Screenshot (255).png'
# 'Screenshot (256).png'
# 'Screenshot (257).png'
# 'Screenshot (258).png'
# 'Screenshot (259).png'
# 'Screenshot (260).png'
# 'Screenshot (261).png'
#  Semster_memos
#  sendmail.ini
# 'SQL Operators (1).pdf'
# 'SQL Operators.pdf'
#  studentDetails_ITA.gsheet
#  TCS-16881A1238.pdf
# 'text mining with python.pptx'
#  U5_Ch1.ppt
#  U5_Ch2.ppt
# 'unit1(a) CC.pdf'
# 'unit-1(b) CC.pdf'
# 'unit-1-written notes.pdf'
#  unit-1-written-notes.pdf
# 'unit-2 CC.docx'
# 'UNIT 3A CC.pdf'
# 'UNIT 3B AND UNIT 4A PART1 CC.pdf'
# 'UNIT4A PART2 CC.pdf'
# 'unit 5 BD.docx'
#  Untitled
#  Untitled0.ipynb
# 'Untitled document.gdoc'
# 'Untitled Jam'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'WORK SHOP LAB MANUAL.docx.gdoc'
# 'WWW as arch.docx'

# %%
data=pd.read_csv('datam.csv' ,encoding="ISO-8859-1")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#        stn_code       sampling_date  ... pm2_5        date
# 0           150  February - M021990  ...   NaN  1990-02-01
# 1           151  February - M021990  ...   NaN  1990-02-01
# 2           152  February - M021990  ...   NaN  1990-02-01
# 3           150     March - M031990  ...   NaN  1990-03-01
# 4           151     March - M031990  ...   NaN  1990-03-01
# ...         ...                 ...  ...   ...         ...
# 435737     SAMP            24-12-15  ...   NaN  2015-12-24
# 435738     SAMP            29-12-15  ...   NaN  2015-12-29
# 435739      NaN                 NaN  ...   NaN         NaN
# 435740      NaN                 NaN  ...   NaN         NaN
# 435741      NaN                 NaN  ...   NaN         NaN
#
# [435742 rows x 13 columns]

# %%
data.fillna(0,inplace=True)
data.tail()
# Out:
#        stn_code sampling_date  ... pm2_5        date
# 435737     SAMP      24-12-15  ...   0.0  2015-12-24
# 435738     SAMP      29-12-15  ...   0.0  2015-12-29
# 435739        0             0  ...   0.0           0
# 435740        0             0  ...   0.0           0
# 435741        0             0  ...   0.0           0
#
# [5 rows x 13 columns]

# %%
def calculate_si(so2):
    si=0
    if (so2<=40):
     si= so2*(50/40)
    if (so2>40 and so2<=80):
     si= 50+(so2-40)*(50/40)
    if (so2>80 and so2<=380):
     si= 100+(so2-80)*(100/300)
    if (so2>380 and so2<=800):
     si= 200+(so2-380)*(100/800)
    if (so2>800 and so2<=1600):
     si= 300+(so2-800)*(100/800)
    if (so2>1600):
     si= 400+(so2-1600)*(100/800)
    return si
data['si']=data['so2'].apply(calculate_si)
df= data[['so2','si']]
df.head()
# Out:
#    so2     si
# 0  4.8  6.000
# 1  3.1  3.875
# 2  6.2  7.750
# 3  6.3  7.875
# 4  4.7  5.875

# %%
def calculate_ni(no2):
    ni=0
    if(no2<=40):
     ni= no2*50/40
    elif(no2>40 and no2<=80):
     ni= 50+(no2-14)*(50/40)
    elif(no2>80 and no2<=180):
     ni= 100+(no2-80)*(100/100)
    elif(no2>180 and no2<=280):
     ni= 200+(no2-180)*(100/100)
    elif(no2>280 and no2<=400):
     ni= 300+(no2-280)*(100/120)
    else:
     ni= 400+(no2-400)*(100/120)
    return ni
data['ni']=data['no2'].apply(calculate_ni)
df= data[['no2','ni']]
df.head()
# Out:
#     no2      ni
# 0  17.4  21.750
# 1   7.0   8.750
# 2  28.5  35.625
# 3  14.7  18.375
# 4   7.5   9.375

# %%
def calculate_(rspm):
    rpi=0
    rpi=rspm
    rpii=0
    if(rpi<=30):
     rpii=rpi*50/30
    elif(rpi>30 and rpi<=60):
     rpii=50+(rpi-30)*50/30
    elif(rpi>60 and rpi<=90):
     rpii=100+(rpi-60)*100/30
    elif(rpi>90 and rpi<=120):
     rpii=200+(rpi-90)*100/30
    elif(rpi>120 and rpi<=250):
     rpii=300+(rpi-120)*(100/130)
    else:
     rpii=400+(rpi-250)*(100/130)
    return rpi
data['rpi']=data['rspm'].apply(calculate_si)
df= data[['rspm','rpi']]
df.tail()
# Out:
#          rspm         rpi
# 435737  143.0  121.000000
# 435738  171.0  130.333333
# 435739    0.0    0.000000
# 435740    0.0    0.000000
# 435741    0.0    0.000000

# %%
def calculate_spi(spm):
    spi=0
    if(spm<=50):
     spi=spm
    if(spm<50 and spm<=100):
     spi=spm
    elif(spm>100 and spm<=250):
     spi= 100+(spm-100)*(100/150)
    elif(spm>250 and spm<=350):
     spi=200+(spm-250)
    elif(spm>350 and spm<=450):
     spi=300+(spm-350)*(100/80)
    else:
     spi=400+(spm-430)*(100/80)
    return spi
data['spi']=data['spm'].apply(calculate_spi)
df= data[['spm','spi']]
df.tail()
# Out:
#         spm  spi
# 435737  0.0  0.0
# 435738  0.0  0.0
# 435739  0.0  0.0
# 435740  0.0  0.0
# 435741  0.0  0.0

# %%
def calculate_aqi(si,ni,spi,rpi):
    aqi=0
    if(si>ni and si>spi and si>rpi):
     aqi=si
    if(spi>si and spi>ni and spi>rpi):
     aqi=spi
    if(ni>si and ni>spi and ni>rpi):
     aqi=ni
    if(rpi>si and rpi>ni and rpi>spi):
     aqi=rpi
    return aqi
data['AQI']=data.apply(lambda x:calculate_aqi(x['si'],x['ni'],x['spi'],x['rpi']),axis=1)
df= data[['sampling_date','state','location','si','ni','rpi','spi','AQI']]
df.head()
# Out:
#         sampling_date           state   location  ...  rpi  spi     AQI
# 0  February - M021990  Andhra Pradesh  Hyderabad  ...  0.0  0.0  21.750
# 1  February - M021990  Andhra Pradesh  Hyderabad  ...  0.0  0.0   8.750
# 2  February - M021990  Andhra Pradesh  Hyderabad  ...  0.0  0.0  35.625
# 3     March - M031990  Andhra Pradesh  Hyderabad  ...  0.0  0.0  18.375
# 4     March - M031990  Andhra Pradesh  Hyderabad  ...  0.0  0.0   9.375
#
# [5 rows x 8 columns]

# %%
loc,dat,aqi=[data['location'],data['date'],data['AQI']]
df=[[],[]]
for i in range(len(loc)):
    if loc[i]=='Hyderabad':
        df[0].append(dat[i])
        df[1].append(aqi[i])
        #df.append(loc[i],dat[i])
df[0]=pd.to_datetime(df[0])

# %%
df
df_new=pd.DataFrame(df,dtype=float)
df_new=df_new.transpose()
df_new.rename(columns={0:'date',1:'AQI'}, inplace=True)

# %%
pk=df_new
pk=pk.set_index('date')

# %%
pk["AQI"] = pd.to_numeric(pk["AQI"])

# %%
pk=pk.resample('MS')["AQI"].mean()

# %%
pk.index
# Out:
# DatetimeIndex(['1990-02-01', '1990-03-01', '1990-04-01', '1990-05-01',
#                '1990-06-01', '1990-07-01', '1990-08-01', '1990-09-01',
#                '1990-10-01', '1990-11-01',
#                ...
#                '2015-03-01', '2015-04-01', '2015-05-01', '2015-06-01',
#                '2015-07-01', '2015-08-01', '2015-09-01', '2015-10-01',
#                '2015-11-01', '2015-12-01'],
#               dtype='datetime64[ns]', name='date', length=311, freq='MS')

# %%
pk.head()
# Out:
# date
# 1990-02-01    22.041667
# 1990-03-01    19.958333
# 1990-04-01    20.333333
# 1990-05-01    17.187500
# 1990-06-01    81.361111
# Freq: MS, Name: AQI, dtype: float64

# %%
pk.sort_values(ascending=False)
pk.plot(figsize=(15,6))

# %%
pk
# Out:
# date
# 1990-02-01     22.041667
# 1990-03-01     19.958333
# 1990-04-01     20.333333
# 1990-05-01     17.187500
# 1990-06-01     81.361111
#                  ...
# 2015-08-01     78.847046
# 2015-09-01     89.582265
# 2015-10-01    109.138889
# 2015-11-01    102.883547
# 2015-12-01    104.152778
# Freq: MS, Name: AQI, Length: 311, dtype: float64

# %%
dc=pd.DataFrame(pk)

# %%
p=dc['AQI'].mean()
p
# Out:
# 127.74802906471142

# %%
dc.plot()

# %%
df1=pd.DataFrame(pk)

# %%
df1.fillna(127.74802906471142,inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 311 entries, 1990-02-01 to 2015-12-01
# Freq: MS
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AQI     311 non-null    float64
# dtypes: float64(1)
# memory usage: 4.9 KB

# %%
train_data=df1.iloc[:263]
test_data=df1.iloc[263:]
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 48 entries, 2012-01-01 to 2015-12-01
# Freq: MS
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AQI     48 non-null     float64
# dtypes: float64(1)
# memory usage: 768.0 bytes

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
fitted_model= ExponentialSmoothing(train_data['AQI'],
                                  trend='mul',
                                  seasonal='mul',
                                  seasonal_periods=12).fit()

# %%
test_predictions=fitted_model.forecast(48)

# %%
fitted_model

# %%
test_predictions
# Out:
# 2012-01-01    141.445407
# 2012-02-01    147.581386
# 2012-03-01    149.797964
# 2012-04-01    142.650988
# 2012-05-01    151.766650
# 2012-06-01    132.283661
# 2012-07-01    123.144637
# 2012-08-01    118.888629
# 2012-09-01    118.777413
# 2012-10-01    136.963130
# 2012-11-01    137.346046
# 2012-12-01    143.937922
# 2013-01-01    127.204185
# 2013-02-01    132.722372
# 2013-03-01    134.715778
# 2013-04-01    128.288384
# 2013-05-01    136.486250
# 2013-06-01    118.964876
# 2013-07-01    110.746001
# 2013-08-01    106.918503
# 2013-09-01    106.818485
# 2013-10-01    123.173200
# 2013-11-01    123.517562
# 2013-12-01    129.445745
# 2014-01-01    114.396820
# 2014-02-01    119.359417
# 2014-03-01    121.152119
# 2014-04-01    115.371858
# 2014-05-01    122.744333
# 2014-06-01    106.987073
# 2014-07-01     99.595704
# 2014-08-01     96.153572
# 2014-09-01     96.063624
# 2014-10-01    110.771688
# 2014-11-01    111.081379
# 2014-12-01    116.412692
# 2015-01-01    102.878945
# 2015-02-01    107.341890
# 2015-03-01    108.954097
# 2015-04-01    103.755813
# 2015-05-01    110.386002
# 2015-06-01     96.215238
# 2015-07-01     89.568058
# 2015-08-01     86.472491
# 2015-09-01     86.391600
# 2015-10-01     99.618805
# 2015-11-01     99.897315
# 2015-12-01    104.691852
# Freq: MS, dtype: float64

# %%
train_data['AQI'].plot(legend=True,label='RT')

# %% [markdown]
# df1

# %%
df1
# Out:
#                    AQI
# date
# 1990-02-01   22.041667
# 1990-03-01   19.958333
# 1990-04-01   20.333333
# 1990-05-01   17.187500
# 1990-06-01   81.361111
# ...                ...
# 2015-08-01   78.847046
# 2015-09-01   89.582265
# 2015-10-01  109.138889
# 2015-11-01  102.883547
# 2015-12-01  104.152778
#
# [311 rows x 1 columns]

# %%
df1.plot()

# %%
train_data['AQI'].plot(legend=True,label="train",figsize=(12,8))
test_data['AQI'].plot(legend=True,label='test')
test_predictions.plot(legend=True,label='Prediction',xlim=['2012-01-01','2015-12-01'])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
test_data.describe()
# Out:
#               AQI
# count   48.000000
# mean    98.475271
# std     12.905446
# min     56.858796
# 25%     93.097770
# 50%    102.241056
# 75%    106.828248
# max    115.019841

# %%
import math
math.sqrt(mean_squared_error(test_data,test_predictions))
# Out:
# 23.95870191977075

# %%
len(test_data)
# Out:
# 48

# %%
len(test_predictions)
# Out:
# 48

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 311 entries, 1990-02-01 to 2015-12-01
# Freq: MS
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AQI     311 non-null    float64
# dtypes: float64(1)
# memory usage: 4.9 KB

# %%
final_model=ExponentialSmoothing(df1["AQI"],trend='mul',seasonal='mul'
                                    ,seasonal_periods=12).fit()

# %%
forecast_pred=final_model.forecast(12)

# %%
df1['AQI'].plot(figsize=(12,8))
forecast_pred.plot()

# %%
#fitted_model.score(test_data)
from statsmodels.tsa.arima_model import ARIMA

# %%
len(train_data)
# Out:
# 263

# %%
len(test_data)
# Out:
# 48

# %%
model_arima = ARIMA (train_data,order=(12,1,12))
model_arima_fit = model_arima.fit()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
   predictions=model_arima_fit.forecast(steps=48)[0]

# %%
predictions
# Out:
# array([165.26094744, 163.93666973, 190.59682873, 208.53663351,
#        201.33551945, 199.00152028, 207.33010468, 203.52789269,
#        218.07721077, 214.9708568 , 207.03182016, 233.26128985,
#        224.54485543, 207.88151179, 216.834909  , 215.95398507,
#        220.23838276, 222.05448244, 213.89020206, 211.29566497,
#        217.27503366, 206.56034131, 194.56038548, 209.35367976,
#        207.23174503, 198.49002681, 200.0805044 , 185.7053493 ,
#        187.87360676, 191.44239779, 178.56892706, 180.96925716,
#        186.38867871, 177.27447255, 168.54828551, 168.42306025,
#        165.54604777, 166.80870248, 170.45785067, 159.00348489,
#        161.06800995, 164.05093904, 150.99605038, 153.41230868,
#        157.96372146, 155.72528942, 158.74227924, 154.60849666])

# %%
len(predictions)
# Out:
# 48

# %%
train_data['AQI'].plot(legend=True,label="train",figsize=(12,8))
test_data['AQI'].plot(legend=True,label='test')
predictions.plot(legend=True,label='Prediction',xlim=['2012-01-01','2015-12-01'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-94bfda98138d> in <module>()
#       1 train_data['AQI'].plot(legend=True,label="train",figsize=(12,8))
#       2 test_data['AQI'].plot(legend=True,label='test')
# ----> 3 predictions.plot(legend=True,label='Prediction',xlim=['2012-01-01','2015-12-01'])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
import math
math.sqrt(mean_squared_error(test_data,predictions))
# Out:
# 94.89345496696232

# %%
model_arima_fit.aic
# Out:
# 2634.2927549065917

# %%
import matplotlib.pyplot as plt

# %%
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
model_ar = AR (train_data) 
model_ar_fit = model_ar.fit()

# %%
predict_ar=model_ar_fit.predict(start=263,end=310) 
predict_ar
# Out:
# 2012-01-01    148.152287
# 2012-02-01    140.076170
# 2012-03-01    140.011733
# 2012-04-01    141.655269
# 2012-05-01    137.984437
# 2012-06-01    140.713405
# 2012-07-01    144.624376
# 2012-08-01    144.422878
# 2012-09-01    143.837596
# 2012-10-01    141.507242
# 2012-11-01    138.114753
# 2012-12-01    137.872027
# 2013-01-01    139.008542
# 2013-02-01    139.915490
# 2013-03-01    140.371278
# 2013-04-01    139.801946
# 2013-05-01    139.795195
# 2013-06-01    139.200454
# 2013-07-01    137.969226
# 2013-08-01    137.627224
# 2013-09-01    137.729834
# 2013-10-01    137.971105
# 2013-11-01    138.426465
# 2013-12-01    138.353845
# 2014-01-01    137.980292
# 2014-02-01    137.669036
# 2014-03-01    137.352067
# 2014-04-01    137.252355
# 2014-05-01    137.214683
# 2014-06-01    137.213264
# 2014-07-01    137.356336
# 2014-08-01    137.365485
# 2014-09-01    137.229242
# 2014-10-01    137.090772
# 2014-11-01    136.929220
# 2014-12-01    136.852012
# 2015-01-01    136.862120
# 2015-02-01    136.865459
# 2015-03-01    136.879348
# 2015-04-01    136.865227
# 2015-05-01    136.814936
# 2015-06-01    136.764165
# 2015-07-01    136.697258
# 2015-08-01    136.649961
# 2015-09-01    136.643483
# 2015-10-01    136.642292
# 2015-11-01    136.643275
# 2015-12-01    136.635150
# Freq: MS, dtype: float64

# %%
len(model_ar_fit.predict(start=263,end=310))
# Out:
# 48

# %%
test_data['AQI']
# Out:
# date
# 2012-01-01    110.566667
# 2012-02-01    108.461538
# 2012-03-01    107.873810
# 2012-04-01    101.611979
# 2012-05-01    106.547872
# 2012-06-01    103.052083
# 2012-07-01     80.629310
# 2012-08-01     96.207317
# 2012-09-01     93.385417
# 2012-10-01    114.244444
# 2012-11-01    109.818376
# 2012-12-01    112.500000
# 2013-01-01    114.127451
# 2013-02-01    108.012195
# 2013-03-01    102.820028
# 2013-04-01    104.761905
# 2013-05-01    111.539474
# 2013-06-01     92.882883
# 2013-07-01     56.858796
# 2013-08-01     76.211623
# 2013-09-01    100.186343
# 2013-10-01     92.177928
# 2013-11-01    115.019841
# 2013-12-01    107.153509
# 2014-01-01     97.757862
# 2014-02-01     96.801724
# 2014-03-01    104.552966
# 2014-04-01    102.092593
# 2014-05-01    106.719828
# 2014-06-01    100.289828
# 2014-07-01     81.300595
# 2014-08-01     80.805060
# 2014-09-01    100.077236
# 2014-10-01     93.169399
# 2014-11-01    102.389520
# 2014-12-01    105.843284
# 2015-01-01    104.926587
# 2015-02-01    102.875479
# 2015-03-01    102.006863
# 2015-04-01     90.649177
# 2015-05-01    100.078431
# 2015-06-01     61.217391
# 2015-07-01     82.003876
# 2015-08-01     78.847046
# 2015-09-01     89.582265
# 2015-10-01    109.138889
# 2015-11-01    102.883547
# 2015-12-01    104.152778
# Freq: MS, Name: AQI, dtype: float64

# %%
len(test_data['AQI'])
# Out:
# 48

# %%
import math
math.sqrt(mean_squared_error(test_data,predict_ar))
# Out:
# 42.07794806635004
